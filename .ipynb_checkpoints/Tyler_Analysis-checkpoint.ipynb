# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

ok_inj_wells = '../Project_1/InjectionWells.csv'
ok_eqs = '../Project_1/okQuakes.csv'

ok_inj_wells_df = pd.read_csv(ok_inj_wells)
ok_eqs_df = pd.read_csv(ok_eqs)

ok_eqs_df.dropna()

ok_eqs_df.drop_duplicates()

ok_inj_wells_df.columns
# Out:
# Index(['API#', 'Operator', 'Operator ID', 'WellType', 'WellName', 'WellNumber',
#        'OrderNumbers', 'Approval Date', 'County', 'Sec', 'Twp', 'Rng', 'QQQQ',
#        'LAT', 'LONG', 'PSI', 'BBLS', 'ZONE', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20'],
#       dtype='object')

# %%
ok_eqs_df
# Out:
#                            time   latitude   longitude  depth   mag magType  \
# 0      1973-03-17T07:43:05.500Z  36.087000 -106.168000   6.00  4.50      mb
# 1      1973-05-25T14:40:13.900Z  33.917000  -90.775000   6.00   NaN     NaN
# 2      1973-09-19T13:28:20.500Z  37.160000 -104.594000   5.00   NaN     NaN
# 3      1973-09-23T03:58:54.900Z  37.148000 -104.571000   5.00  4.20      mb
# 4      1974-02-15T13:33:49.200Z  36.500000 -100.693000  24.00  4.50      mb
# ...                         ...        ...         ...    ...   ...     ...
# 13949  2016-09-20T05:38:38.350Z  36.373500  -96.818700   4.69  2.30      ml
# 13950  2016-09-20T06:36:35.520Z  36.412200  -96.882400   4.41  1.40      ml
# 13951  2016-09-20T16:01:08.610Z  37.277167  -98.072667   5.85  2.43      ml
# 13952  2016-09-20T17:31:48.380Z  36.939300  -97.896000   2.32  3.00   mb_lg
# 13953  2016-09-20T17:45:59.920Z  36.940500  -97.906300   7.20  2.50   mb_lg
#
#         nst    gap     dmin   rms  ...                   updated  \
# 0       NaN    NaN      NaN   NaN  ...  2014-11-06T23:21:10.078Z
# 1       NaN    NaN      NaN   NaN  ...  2014-11-06T23:21:12.859Z
# 2       NaN    NaN      NaN   NaN  ...  2014-11-06T23:21:20.295Z
# 3       NaN    NaN      NaN   NaN  ...  2014-11-06T23:21:20.346Z
# 4       NaN    NaN      NaN   NaN  ...  2014-11-06T23:21:22.859Z
# ...     ...    ...      ...   ...  ...                       ...
# 13949   NaN   54.0  0.01800  0.16  ...  2016-09-20T16:13:04.040Z
# 13950   NaN   59.0  0.02500  0.18  ...  2016-09-20T16:21:03.040Z
# 13951  15.0  237.0  0.05185  0.04  ...  2016-09-20T19:08:23.720Z
# 13952   NaN   37.0  0.05600  0.18  ...  2016-09-20T17:43:43.040Z
# 13953   NaN   39.0  0.04800  0.35  ...  2016-09-20T19:48:57.396Z
#
#                               place        type horizontalError depthError  \
# 0                        New Mexico  earthquake             NaN        NaN
# 1                       Mississippi  earthquake             NaN        NaN
# 2                          Colorado  earthquake             NaN        NaN
# 3                          Colorado  earthquake             NaN        NaN
# 4                          Oklahoma  earthquake             NaN        NaN
# ...                             ...         ...             ...        ...
# 13949   4km NNW of Pawnee, Oklahoma  earthquake            0.90       1.80
# 13950   10km NW of Pawnee, Oklahoma  earthquake            0.80       2.00
# 13951     4km WSW of Harper, Kansas  earthquake            0.38       0.33
# 13952  20km NW of Medford, Oklahoma  earthquake            1.00       3.70
# 13953  21km NW of Medford, Oklahoma  earthquake            1.00       3.40
#
#        magError  magNst    status  locationSource magSource
# 0           NaN     NaN  reviewed              us        us
# 1           NaN     NaN  reviewed               s        us
# 2           NaN     NaN  reviewed              us        us
# 3           NaN     NaN  reviewed              us        us
# 4           NaN     NaN  reviewed              us        us
# ...         ...     ...       ...             ...       ...
# 13949     0.059    38.0  reviewed              us        us
# 13950     0.062    34.0  reviewed              us        us
# 13951     0.179    17.0  reviewed            ismp      ismp
# 13952     0.076    45.0  reviewed              us        us
# 13953     0.170     9.0  reviewed              us        us
#
# [13954 rows x 22 columns]

# %%
places = ok_eqs_df["place"].unique()
okplaces_df = ok_eqs_df.loc[ok_eqs_df["place"].str.contains("Oklahoma")]
okplaces_df
# Out:
#                            time  latitude  longitude  depth  mag magType  nst  \
# 4      1974-02-15T13:33:49.200Z   36.5000  -100.6930  24.00  4.5      mb  NaN
# 21     1974-12-16T02:30:21.400Z   35.3300   -97.4800  10.00  2.6      ml  NaN
# 34     1975-09-13T01:25:02.800Z   34.1390   -97.3690   5.00  3.4      lg  NaN
# 36     1975-10-12T02:58:11.200Z   34.8160   -97.4060  20.00  3.2      lg  NaN
# 37     1975-11-29T14:29:40.900Z   34.5210   -97.3470   5.00  3.5      lg  NaN
# ...                         ...       ...        ...    ...  ...     ...  ...
# 13948  2016-09-20T04:59:11.140Z   36.9246   -97.8946   2.62  3.9     mwr  NaN
# 13949  2016-09-20T05:38:38.350Z   36.3735   -96.8187   4.69  2.3      ml  NaN
# 13950  2016-09-20T06:36:35.520Z   36.4122   -96.8824   4.41  1.4      ml  NaN
# 13952  2016-09-20T17:31:48.380Z   36.9393   -97.8960   2.32  3.0   mb_lg  NaN
# 13953  2016-09-20T17:45:59.920Z   36.9405   -97.9063   7.20  2.5   mb_lg  NaN
#
#         gap   dmin   rms  ...                   updated  \
# 4       NaN    NaN   NaN  ...  2014-11-06T23:21:22.859Z
# 21      NaN    NaN   NaN  ...  2014-11-06T23:21:27.851Z
# 34      NaN    NaN   NaN  ...  2014-11-06T23:21:31.918Z
# 36      NaN    NaN   NaN  ...  2014-11-06T23:21:32.248Z
# 37      NaN    NaN   NaN  ...  2014-11-06T23:21:32.839Z
# ...     ...    ...   ...  ...                       ...
# 13948  18.0  0.063  0.46  ...  2016-09-20T19:15:48.944Z
# 13949  54.0  0.018  0.16  ...  2016-09-20T16:13:04.040Z
# 13950  59.0  0.025  0.18  ...  2016-09-20T16:21:03.040Z
# 13952  37.0  0.056  0.18  ...  2016-09-20T17:43:43.040Z
# 13953  39.0  0.048  0.35  ...  2016-09-20T19:48:57.396Z
#
#                                     place        type horizontalError  \
# 4                                Oklahoma  earthquake             NaN
# 21     Oklahoma City urban area, Oklahoma  earthquake             NaN
# 34                               Oklahoma  earthquake             NaN
# 36                               Oklahoma  earthquake             NaN
# 37                               Oklahoma  earthquake             NaN
# ...                                   ...         ...             ...
# 13948        19km NW of Medford, Oklahoma  earthquake             0.8
# 13949         4km NNW of Pawnee, Oklahoma  earthquake             0.9
# 13950         10km NW of Pawnee, Oklahoma  earthquake             0.8
# 13952        20km NW of Medford, Oklahoma  earthquake             1.0
# 13953        21km NW of Medford, Oklahoma  earthquake             1.0
#
#       depthError  magError  magNst    status  locationSource magSource
# 4            NaN       NaN     NaN  reviewed              us        us
# 21           NaN       NaN     NaN  reviewed               m       tul
# 34           NaN       NaN     NaN  reviewed              us       tul
# 36           NaN       NaN     NaN  reviewed              us       tul
# 37           NaN       NaN     NaN  reviewed              us       slm
# ...          ...       ...     ...       ...             ...       ...
# 13948        5.7     0.036    75.0  reviewed              us        us
# 13949        1.8     0.059    38.0  reviewed              us        us
# 13950        2.0     0.062    34.0  reviewed              us        us
# 13952        3.7     0.076    45.0  reviewed              us        us
# 13953        3.4     0.170     9.0  reviewed              us        us
#
# [7853 rows x 22 columns]

# %%
#Do the average daily PSI rates have more earthquakes around them?

#sort wells df by PSI
#plot lat/longs of earthquakes
#plot lat/longs of wells
#do locations overlap?
#is there a correlation to PSI?

# %%
#plot lat/longs of earthquakes
eqs_x = okplaces_df["latitude"]
eqs_y = okplaces_df["longitude"]
#plot lat/longs of wells
wells_x = ok_inj_wells_df["LAT"]
wells_y = ok_inj_wells_df["LONG"]
plt.figure(figsize = (15,15))
plt.scatter(eqs_x, eqs_y, c="r", s=7, alpha = .5)
plt.scatter(wells_x, wells_y, c="b", s= 7, alpha = .5)
plt.xlim(min(eqs_x),max(eqs_x))
plt.ylim(min(eqs_y),max(eqs_y))
yticks = np.arange((-102.5),(-94.5), .25)
xticks = np.arange(33.75, 37.25, .25)
plt.yticks(yticks)
plt.xticks(xticks)
plt.show()
